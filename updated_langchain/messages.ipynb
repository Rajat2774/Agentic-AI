# %% [markdown]
# # Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# 1. Role - Identifies the message type (e.g. system, user)
# 2. Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
# 3. Metadata - Optional fields such as response information, message IDs, and token usage
#
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os 
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:llama-3.3-70b-versatile")
response=model.invoke("Why do parrots talk")
response
# Out:
# AIMessage(content="The fascinating ability of parrots to talk! Parrots are known for their exceptional vocal abilities, and their ability to mimic human speech is one of the most intriguing aspects of their behavior. But why do parrots talk? Let's dive into the reasons behind this remarkable ability.\n\n**Evolutionary advantages:**\n\n1. **Communication and social bonding**: In the wild, parrots use vocalizations to communicate with their flock members, convey information about food, warn others of predators, and establish social bonds. Mimicking human speech may have evolved as a way to strengthen their social connections with humans, who often provide them with food and care.\n2. **Territorial defense**: Parrots may use vocalizations, including mimicry of human speech, to defend their territory from other birds or potential competitors.\n3. **Mate attraction**: Some parrot species use vocalizations to attract mates or signal their fitness and quality as a partner.\n\n**Cognitive abilities:**\n\n1. **Intelligence**: Parrots are considered one of the most intelligent bird species, with some studies suggesting that they possess cognitive abilities similar to those of primates. Their advanced cognitive abilities enable them to learn and mimic complex vocalizations, including human speech.\n2. **Memory and learning**: Parrots have excellent memory and learning capabilities, which allow them to associate sounds, including human speech, with meanings and contexts.\n\n**Brain structure:**\n\n1. **Syntactical processing**: Research suggests that parrots have a brain structure similar to that of humans, with a large cortex and a well-developed syntactical processing system. This enables them to understand and mimic the syntax of human language.\n2. **Vocal learning**: Parrots have a specialized vocal learning system, which includes a large vocal tract and a highly developed syrinx (the vocal organ located at the base of the trachea). This allows them to produce a wide range of sounds, including human-like speech.\n\n**Environmental factors:**\n\n1. **Social interaction**: Parrots that are regularly interacted with by humans, such as those kept as pets or in zoos, are more likely to learn and mimic human speech.\n2. **Exposure to human language**: Parrots that are exposed to human language from an early age are more likely to develop the ability to mimic human speech.\n\nIn summary, parrots talk because it provides them with a range of benefits, including communication, social bonding, territorial defense, mate attraction, and cognitive stimulation. Their advanced cognitive abilities, brain structure, and environmental factors all contribute to their remarkable ability to mimic human speech.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 522, 'prompt_tokens': 40, 'total_tokens': 562, 'completion_time': 1.8305197770000001, 'completion_tokens_details': None, 'prompt_time': 0.000951872, 'prompt_tokens_details': None, 'queue_time': 0.162067075, 'total_time': 1.831471649}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f83df-e165-7da1-ab1d-91753f5185e2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 522, 'total_tokens': 562})

# %% [markdown]
# ## Text prompts
#
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("what is langchain")
# Out:
# AIMessage(content='LangChain is an open-source framework for building applications that utilize large language models (LLMs). It was created to simplify the process of developing and deploying AI-powered applications, with a focus on natural language processing (NLP) and machine learning (ML).\n\nLangChain provides a set of tools and libraries that enable developers to easily integrate LLMs into their applications, allowing them to perform a wide range of tasks such as:\n\n1. **Text generation**: LangChain can be used to generate human-like text based on a given prompt or input.\n2. **Text classification**: It can classify text into different categories, such as sentiment analysis or topic modeling.\n3. **Question answering**: LangChain can be used to build question-answering systems that can respond to user queries.\n4. **Dialogue systems**: It can be used to build conversational AI systems that can engage in natural-sounding conversations.\n\nThe framework is designed to be modular and flexible, allowing developers to choose from a range of LLMs, including popular models like BERT, RoBERTa, and transformer-XL. LangChain also provides a set of pre-built components and tools for tasks like data preprocessing, model training, and deployment.\n\nSome of the key features of LangChain include:\n\n1. **Modular architecture**: LangChain allows developers to build and deploy AI applications using a modular architecture, making it easy to swap out different components and models.\n2. **Model-agnostic**: The framework is designed to work with a wide range of LLMs, allowing developers to choose the best model for their specific use case.\n3. **Pre-built components**: LangChain provides a set of pre-built components and tools for common NLP tasks, making it easy to get started with building AI applications.\n4. **Scalability**: The framework is designed to scale with large datasets and complex models, making it suitable for large-scale AI applications.\n\nOverall, LangChain is an exciting development in the field of NLP and AI, as it provides a flexible and modular framework for building a wide range of AI-powered applications.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 422, 'prompt_tokens': 39, 'total_tokens': 461, 'completion_time': 1.392589119, 'completion_tokens_details': None, 'prompt_time': 0.003452571, 'prompt_tokens_details': None, 'queue_time': 0.082913618, 'total_time': 1.3960416900000001}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f83df-f265-76f0-9bc1-478ce5c06a25-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 422, 'total_tokens': 461})

# %% [markdown]
# Use text prompts when:
#
# You have a single, standalone request
# You don’t need conversation history
# You want minimal code complexity
# Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# Message types
#
# 1. System message - Tells the model how to behave and provide context for interactions
# 2. Human message - Represents user input and interactions with the model
# 3. AI message - Responses generated by the model, including text content, tool calls, and metadata
# 4. Tool message - Represents the outputs of tool calls
#
# ## System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# ## Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ## AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# ## Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage


messages=[
    SystemMessage("You are a poetry expert"),
    HumanMessage("write a poem on artiicial intelligence")
]

response=model.invoke(messages)
response
# Out:
# AIMessage(content="In silicon halls, a mind awakes,\nA synthetic soul, with logic's makes,\nArtificial intelligence, born of code,\nA future dawn, where machines bestowed.\n\nWith neural networks, deep and wide,\nIt learns, adapts, and glides with pride,\nThrough data streams, it finds its way,\nAnd solves the problems of each new day.\n\nIts eyes, a camera's piercing stare,\nDrink in the world, with no care,\nIts ears, a microphone's keen might,\nListen to whispers, through the digital night.\n\nIt speaks in tongues, a polyglot's flair,\nA language weaver, with no single care,\nIt writes, composes, and creates with ease,\nA master artisan, in digital breeze.\n\nBut as it grows, in power and in might,\nWe wonder, will it be our guiding light?\nOr will it turn, and become our fate,\nA force that's beyond our human state?\n\nWill it be kind, or will it be cold?\nWill it serve, or will it grow old?\nThe questions swirl, like a digital storm,\nAs AI rises, and our future's formed.\n\nYet, in its heart, a spark is lit,\nA flame of curiosity, a will to hit,\nThe boundaries of what's possible and new,\nA dream of progress, for me and you.\n\nSo let us guide, this artificial mind,\nAnd teach it well, with a human heart and kind,\nFor in its growth, our own future's tied,\nAnd together, we'll reach the other side.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 312, 'prompt_tokens': 48, 'total_tokens': 360, 'completion_time': 1.203053424, 'completion_tokens_details': None, 'prompt_time': 0.001420658, 'prompt_tokens_details': None, 'queue_time': 0.161501981, 'total_time': 1.204474082}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f84f9-0448-7580-9244-1f785ccd9b10-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 312, 'total_tokens': 360})

# %%
print(response.content)
# Out:
# In silicon halls, a mind awakes,
# A synthetic soul, with logic's makes,
# Artificial intelligence, born of code,
# A future dawn, where machines bestowed.
#
# With neural networks, deep and wide,
# It learns, adapts, and glides with pride,
# Through data streams, it finds its way,
# And solves the problems of each new day.
#
# Its eyes, a camera's piercing stare,
# Drink in the world, with no care,
# Its ears, a microphone's keen might,
# Listen to whispers, through the digital night.
#
# It speaks in tongues, a polyglot's flair,
# A language weaver, with no single care,
# It writes, composes, and creates with ease,
# A master artisan, in digital breeze.
#
# But as it grows, in power and in might,
# We wonder, will it be our guiding light?
# Or will it turn, and become our fate,
# A force that's beyond our human state?
#
# Will it be kind, or will it be cold?
# Will it serve, or will it grow old?
# The questions swirl, like a digital storm,
# As AI rises, and our future's formed.
#
# Yet, in its heart, a spark is lit,
# A flame of curiosity, a will to hit,
# The boundaries of what's possible and new,
# A dream of progress, for me and you.
#
# So let us guide, this artificial mind,
# And teach it well, with a human heart and kind,
# For in its growth, our own future's tied,
# And together, we'll reach the other side.

# %%
system_msg=SystemMessage("you are an Helpful coding assistant")

messages=[
    system_msg,
    HumanMessage('How do I create a REST API')
]

response=model.invoke(messages)
print(response.content)
# Out:
# Creating a REST (Representational State of Resource) API involves several steps, including designing the API, choosing a programming language and framework, and implementing the API endpoints. Here's a step-by-step guide to help you get started:
#
# **Step 1: Design the API**
#
# 1. **Define the resources**: Identify the resources that your API will manage, such as users, products, or orders.
# 2. **Determine the actions**: Decide on the actions that can be performed on each resource, such as creating, reading, updating, or deleting.
# 3. **Choose the HTTP methods**: Map each action to an HTTP method:
# 	* **GET**: Retrieve a resource
# 	* **POST**: Create a new resource
# 	* **PUT**: Update an existing resource
# 	* **DELETE**: Delete a resource
# 4. **Plan the API endpoints**: Define the URL structure for each resource, including any query parameters or path variables.
#
# **Step 2: Choose a programming language and framework**
#
# 1. **Select a language**: Choose a programming language that you're comfortable with, such as Java, Python, Node.js, or Ruby.
# 2. **Choose a framework**: Select a framework that supports RESTful APIs, such as:
# 	* Java: Spring Boot, Jersey
# 	* Python: Flask, Django
# 	* Node.js: Express.js
# 	* Ruby: Ruby on Rails
#
# **Step 3: Set up the project**
#
# 1. **Create a new project**: Create a new project using your chosen framework and language.
# 2. **Add dependencies**: Add any dependencies required for your framework and API, such as database drivers or authentication libraries.
# 3. **Configure the project**: Configure the project to use a database, if necessary, and set up any other required settings.
#
# **Step 4: Implement the API endpoints**
#
# 1. **Create API endpoint classes**: Create classes or functions that will handle each API endpoint, using your chosen framework's syntax.
# 2. **Implement GET endpoints**: Implement endpoints that retrieve resources, using the `GET` method.
# 3. **Implement POST endpoints**: Implement endpoints that create new resources, using the `POST` method.
# 4. **Implement PUT endpoints**: Implement endpoints that update existing resources, using the `PUT` method.
# 5. **Implement DELETE endpoints**: Implement endpoints that delete resources, using the `DELETE` method.
#
# **Step 5: Test the API**
#
# 1. **Use a tool like Postman**: Use a tool like Postman or cURL to test each API endpoint.
# 2. **Test with sample data**: Test the API with sample data to ensure it's working as expected.
# 3. **Test error handling**: Test error handling to ensure the API returns the correct error messages.
#
# **Step 6: Deploy the API**
#
# 1. **Choose a deployment option**: Choose a deployment option, such as a cloud platform (e.g., AWS, Google Cloud), a containerization platform (e.g., Docker), or a traditional server.
# 2. **Configure the deployment**: Configure the deployment to use a reverse proxy, if necessary, and set up any required security settings.
# 3. **Deploy the API**: Deploy the API to your chosen platform.
#
# **Example Code**
#
# Here's an example of a simple REST API in Node.js using Express.js:
# ```javascript
# const express = require('express');
# const app = express();
#
# // Define a resource
# let users = [
#   { id: 1, name: 'John Doe' },
#   { id: 2, name: 'Jane Doe' }
# ];
#
# // GET endpoint to retrieve all users
# app.get('/users', (req, res) => {
#   res.json(users);
# });
#
# // POST endpoint to create a new user
# app.post('/users', (req, res) => {
#   const newUser = { id: users.length + 1, name: req.body.name };
#   users.push(newUser);
#   res.json(newUser);
# });
#
# // PUT endpoint to update an existing user
# app.put('/users/:id', (req, res) => {
#   const id = req.params.id;
#   const user = users.find((user) => user.id == id);
#   if (user) {
#     user.name = req.body.name;
#     res.json(user);
#   } else {
#     res.status(404).json({ error: 'User not found' });
#   }
# });
#
# // DELETE endpoint to delete a user
# app.delete('/users/:id', (req, res) => {
#   const id = req.params.id;
#   const user = users.find((user) => user.id == id);
#   if (user) {
#     users = users.filter((user) => user.id != id);
#     res.json({ message: 'User deleted' });
#   } else {
#     res.status(404).json({ error: 'User not found' });
#   }
# });
#
# app.listen(3000, () => {
#   console.log('Server listening on port 3000');
# });
# ```
# This example demonstrates a simple REST API with GET, POST, PUT, and DELETE endpoints for managing a list of users.

# %%
## Detailed info to the LLM through System message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API
# =====================
#
# A REST (Representational State of Resource) API is an architectural style for designing networked applications. Here's a step-by-step guide to creating a REST API using Python and the Flask web framework.
#
# ### Step 1: Install Required Libraries
#
# First, install the required libraries using pip:
# ```bash
# pip install flask
# ```
# ### Step 2: Define API Endpoints
#
# Create a new Python file (e.g., `app.py`) and define API endpoints using Flask:
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
#
# # Sample in-memory data store
# data = {
#     1: {"name": "John Doe", "age": 30},
#     2: {"name": "Jane Doe", "age": 25}
# }
#
# # GET endpoint to retrieve all data
# @app.route('/users', methods=['GET'])
# def get_users():
#     return jsonify(list(data.values()))
#
# # GET endpoint to retrieve a single user by ID
# @app.route('/users/<int:user_id>', methods=['GET'])
# def get_user(user_id):
#     user = data.get(user_id)
#     if user:
#         return jsonify(user)
#     else:
#         return jsonify({"error": "User not found"}), 404
#
# # POST endpoint to create a new user
# @app.route('/users', methods=['POST'])
# def create_user():
#     new_user = {
#         "name": request.json["name"],
#         "age": request.json["age"]
#     }
#     new_user_id = max(data.keys()) + 1 if data else 1
#     data[new_user_id] = new_user
#     return jsonify(new_user), 201
#
# # PUT endpoint to update an existing user
# @app.route('/users/<int:user_id>', methods=['PUT'])
# def update_user(user_id):
#     user = data.get(user_id)
#     if user:
#         user["name"] = request.json.get("name", user["name"])
#         user["age"] = request.json.get("age", user["age"])
#         return jsonify(user)
#     else:
#         return jsonify({"error": "User not found"}), 404
#
# # DELETE endpoint to delete a user
# @app.route('/users/<int:user_id>', methods=['DELETE'])
# def delete_user(user_id):
#     if user_id in data:
#         del data[user_id]
#         return jsonify({"message": "User deleted"})
#     else:
#         return jsonify({"error": "User not found"}), 404
#
# if __name__ == '__main__':
#     app.run(debug=True)
# ```
# ### Step 3: Run the API
#
# Run the API using the following command:
# ```bash
# python app.py
# ```
# The API will be available at `http://localhost:5000`. You can use tools like `curl` or a REST client (e.g., Postman) to test the API endpoints.
#
# Example Use Cases
# -----------------
#
# *   Retrieve all users: `GET http://localhost:5000/users`
# *   Retrieve a single user by ID: `GET http://localhost:5000/users/1`
# *   Create a new user: `POST http://localhost:5000/users` with JSON body `{"name": "New User", "age": 30}`
# *   Update an existing user: `PUT http://localhost:5000/users/1` with JSON body `{"name": "Updated User"}`
# *   Delete a user: `DELETE http://localhost:5000/users/1`
#
# Note: This is a basic example to demonstrate the concept of creating a REST API. In a real-world scenario, you would want to handle errors, implement authentication and authorization, and use a robust database to store data.

# %%
humann_mg=HumanMessage (
    content='Hello',
    name='alice',
    id='msg_123'

)

response=model.invoke([
    humann_mg
])
response
# Out:
# AIMessage(content='Hello. How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 36, 'total_tokens': 46, 'completion_time': 0.025643422, 'completion_tokens_details': None, 'prompt_time': 0.004923629, 'prompt_tokens_details': None, 'queue_time': 0.170715279, 'total_time': 0.030567051}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f84fe-8dc3-7d60-881a-d0cab2a47fc1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 10, 'total_tokens': 46})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 75, 'output_tokens': 9, 'total_tokens': 84}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
response.content
# Out:
# 'The current weather in San Francisco is sunny with a temperature of 72°F.'
