# %% [markdown]
# ## Models integration

# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["Groq_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_GENAI_API_KEY"] = os.getenv("GOOGLE_GENAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model(
    model="llama-3.3-70b-versatile",
    model_provider="groq"
)

# %%
llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.9', 'langchain': '1.3.14'}}, output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000019B19DC0440>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000019B19DC0EC0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
#invoke the model with a prompt

response = llm.invoke("Write a poem about the beauty of nature.")

# %%
response
# Out:
# AIMessage(content="In twilight's hush, where forest dreams,\nA gentle breeze awakens trees,\nTheir leafy whispers weave a spell,\nAs nature's beauty starts to swell.\n\nThe sun rises high and bright,\nPainting the sky with colors light,\nSoft pinks and blushing peaches fade,\nInto a canvas of turquoise shade.\n\nThe mountains stand, a majestic sight,\nTheir rugged peaks, a challenge to the light,\nThe rivers flow, a winding stream,\nThat echoes secrets, in a gentle dream.\n\nThe flowers bloom, a vibrant hue,\nA rainbow's splendor, both old and new,\nTheir sweet fragrance wafts, a perfume so fine,\nInviting all, to nature's divine.\n\nThe stars appear, a twinkling show,\nA celestial display, in all its glow,\nThe moon, a glowing orb, a beacon bright,\n Illuminates the night, with gentle light.\n\nIn nature's beauty, we find our peace,\nA sense of calm, our worries release,\nA connection to the earth, so strong and deep,\nA reminder of the beauty, that we keep.\n\nSo let us cherish, this gift so rare,\nAnd preserve the beauty, that's beyond compare,\nFor in nature's splendor, we find our way,\nTo a world of wonder, in a brand new day.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 263, 'prompt_tokens': 44, 'total_tokens': 307, 'completion_time': 0.755628463, 'completion_tokens_details': None, 'prompt_time': 0.001932986, 'prompt_tokens_details': None, 'queue_time': 0.058462383, 'total_time': 0.757561449}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f7f5f-ddb0-7440-9cac-c093ef44cccc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 263, 'total_tokens': 307})

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

model = init_chat_model(
    model="gemini-3.1-flash-lite",
    model_provider="google_genai",
)

response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'Parrots talk primarily because they are **highly social, intelligent creatures** that use vocal mimicry as a survival strategy. In the wild, their ability to imitate sounds is a vital tool for bonding, maintaining flock cohesion, and navigating their environment.\n\nHere is a breakdown of why they do it:\n\n### 1. Social Integration (The "Flock" Mentality)\nIn the wild, parrots live in tight-knit social groups. They communicate with other members of their flock using specific calls. When a parrot is kept as a pet, its human family becomes its "flock." Parrots have an innate drive to fit in, so they mimic the sounds they hear most often—which, in your home, happens to be human speech. By speaking, they are essentially trying to "talk" to you the way they would talk to their flock mates.\n\n### 2. Reinforcement and Attention\nParrots are extremely intelligent and observant. They quickly learn that making certain sounds results in a reaction from their humans.\n*   **The Reward System:** If a parrot says "Hello" and you smile, talk back, or give them a treat, the bird realizes that specific sound creates a positive outcome. They repeat the sound because it is a successful way to get your attention or a reward.\n*   **Contextual Association:** Parrots often learn to use specific words in specific contexts (e.g., saying "Bye-bye" when someone grabs their keys or "Yum" when they see food) because they have observed the pattern of those events.\n\n### 3. Brain Structure (Vocal Learning)\nMost birds have simple vocalizations, but parrots (along with songbirds and hummingbirds) have a specialized brain structure called the **"syllable engine"** or "song system."\n*   Parrots have extra sets of neural pathways that allow them to control their vocal organs with incredible precision.\n*   This biological equipment allows them to mimic complex sounds—like sirens, doorbells, microwave beeps, and human words—that other animals simply cannot replicate.\n\n### 4. Curiosity and Play\nParrots are naturally curious and playful animals. Mimicry is a form of cognitive stimulation for them. Just as a human might play a puzzle game, a parrot might experiment with making new sounds just to see what happens or because they find the sound interesting. It is a way for them to practice their vocal muscles and express themselves.\n\n### 5. Territorial/Defense Signaling\nSometimes, parrots mimic sounds to defend their territory or respond to environmental stimuli. If a parrot learns that a doorbell sound often precedes the arrival of a stranger, they might mimic the doorbell when they feel excited or anxious about someone approaching the house.\n\n---\n\n### Do they understand what they are saying?\nWhile parrots are incredibly smart, they generally **do not understand language in the way humans do.** They don\'t typically grasp grammar or abstract concepts. However, through intensive training (like the famous work done with Alex the African Grey parrot), they can learn to associate specific words with objects, colors, or feelings. \n\nWhen your parrot talks to you, they aren\'t just "parroting" sounds; they are actively **engaging in a social interaction**, using the only "language" they know to connect with you.', 'extras': {'signature': 'EjQKMgERTTIPMfEVM5mTmmqBmggb/nMimMN9Tq7cBUxsvJgXgofCHmfFIBt5BA7rMuu2VH0p'}}]

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model("groq:llama-3.3-70b-versatile")
response=model.invoke("Why do parrots talk")
response
# Out:
# AIMessage(content="Parrots are known for their remarkable ability to mimic human speech and other sounds, but why do they do it? The answer lies in their evolution, behavior, and cognitive abilities. Here are some reasons why parrots talk:\n\n1. **Communication**: In the wild, parrots use vocalizations to communicate with each other. They use a variety of calls, chirps, and whistles to convey information about food, predators, and potential mates. By mimicking human speech, parrots may be attempting to communicate with their human caregivers or other parrots.\n2. **Social bonding**: Parrots are highly social animals that thrive on interaction. By mimicking human speech, they may be trying to form a bond with their human caregivers or other parrots. Talking can be a way for parrots to initiate or maintain social interactions.\n3. **Learning and play**: Parrots are intelligent birds that are known for their curiosity and love of learning. Mimicking human speech can be a form of play or a way for parrots to learn new sounds and vocalizations.\n4. **Attention seeking**: Parrots may talk to get attention from their human caregivers. By mimicking human speech, they may be able to initiate interactions or receive rewards, such as food or affection.\n5. **Vocalization instinct**: Some scientists believe that parrots have an innate instinct to vocalize, which is triggered by hearing human speech. This instinct may be linked to their natural behavior of mimicking other sounds in their environment, such as bird calls or other noises.\n6. **Brain structure**: Parrots have a large brain-to-body mass ratio, which suggests that they have a high level of cognitive ability. Their brain structure, particularly the syrinx (the vocal organ located at the base of the trachea), is well-suited for producing complex vocalizations, including human-like speech.\n7. **Evolutionary advantage**: In the wild, parrots that can mimic human speech or other sounds may have an evolutionary advantage. For example, they may be able to warn other parrots of potential predators or attract a mate by mimicking a desirable trait.\n\nIt's worth noting that not all parrots are capable of talking, and some species are more skilled at mimicking human speech than others. The African Grey Parrot, Amazon parrots, and Macaws are known for their exceptional talking abilities, while other species, such as cockatiels and budgies, may be less proficient.\n\nOverall, parrots talk because it is a natural behavior that is shaped by their evolution, social behavior, and cognitive abilities. By understanding why parrots talk, we can better appreciate these remarkable birds and provide them with the care and attention they need to thrive.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 552, 'prompt_tokens': 40, 'total_tokens': 592, 'completion_time': 2.021433416, 'completion_tokens_details': None, 'prompt_time': 0.004022788, 'prompt_tokens_details': None, 'queue_time': 0.052803972, 'total_time': 2.025456204}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f8034-be83-7773-8c4d-743b135032cc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 552, 'total_tokens': 592})

# %%
from langchain_groq import ChatGroq

model=ChatGroq(model="llama-3.3-70b-versatile")
response=model.invoke("Why do parrots talk")
response
# Out:
# AIMessage(content="Parrots are known for their ability to mimic human speech and other sounds, but why do they do it? The answer lies in their evolution, behavior, and social interactions.\n\n**Mimicry as a form of communication**\n\nIn the wild, parrots use vocalizations to communicate with each other. They have a wide range of calls, chirps, and whistles to convey information, warnings, and emotions. Mimicry is an extension of this communication system. By imitating sounds they hear, parrots can:\n\n1. **Learn and understand their environment**: Parrots learn to associate sounds with meanings, such as the call of a predator or the sound of food being prepared.\n2. **Interact with other parrots**: Mimicry helps parrots to bond, play, and even flirt with each other.\n3. **Establish dominance or submission**: By mimicking the calls of other parrots, a parrot can signal its dominance or submission, helping to maintain social order within the flock.\n\n**Why parrots mimic human speech**\n\nWhen parrots are kept as pets or in captivity, they often learn to mimic human speech as a way to:\n\n1. **Get attention**: Parrots may learn to mimic human words or phrases to get attention, food, or affection from their owners.\n2. **Communicate with humans**: Parrots may use human speech to convey their needs or wants, such as asking for food or water.\n3. **Imitate and learn**: Parrots are intelligent birds, and they enjoy learning and imitating new sounds, including human speech.\n\n**Brain structure and cognitive abilities**\n\nParrots have a unique brain structure that allows them to mimic sounds and learn complex behaviors. Their brain-to-body mass ratio is similar to that of primates, and they have a large cortex-to-brain mass ratio, which suggests advanced cognitive abilities. This enables them to:\n\n1. **Process and store auditory information**: Parrots can learn and remember a wide range of sounds, including human speech.\n2. **Associate sounds with meanings**: Parrots can understand the context and meaning of the sounds they mimic, including human words and phrases.\n\nIn summary, parrots talk because it's an essential part of their communication system, allowing them to interact with their environment, socialize with other parrots, and even communicate with humans. Their advanced cognitive abilities and brain structure make them one of the most skilled mimics in the animal kingdom.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 495, 'prompt_tokens': 40, 'total_tokens': 535, 'completion_time': 1.413862111, 'completion_tokens_details': None, 'prompt_time': 0.003194988, 'prompt_tokens_details': None, 'queue_time': 0.162449551, 'total_time': 1.417057099}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f8037-d6ac-7553-8e55-fdc47de41c72-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 495, 'total_tokens': 535})
